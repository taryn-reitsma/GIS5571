# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.11/site-packages/arcgis/gis/__init__.py:731: UserWarning: You are logged on as reits041_UMN with an administrator role, proceed with caution.
#   warnings.warn(

# %% [markdown]
# #### Now you are ready to start!

# %%
#Packages
import requests
import pandas as pd
import zipfile
import os
import io
from arcgis import features, GeoAccessor, GeoSeriesAccessor

# %%
#Minnesota Geospatial Commons
request = requests.get('https://gisdata.mn.gov/api/3/action/package_show?id=struc-roadway-weather-sites')
response = request.json()
df=pd.json_normalize(response)
directory= '/arcgis/home/'
    
zip_url= response['result']['resources'][2]['url']
zip_response= requests.get(zip_url)
zip_path ='/arcgis/home/roadway_weather_sites.zip'


with open(zip_path, 'wb') as file:
    file.write(zip_response.content)
    
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(directory)

# %%
#Upload to AGOL content
zip_file= '/arcgis/home/roadway_weather_sites.zip'
file_path = os.path.join('arcgis/home',zip_file )
item_properties = {
    'title': 'Minnesota Geospatial Commons: Roadway Weather Information Sites in MN',
    'tags': 'shapefile, weather, roadway',
    'type': 'Shapefile'
}

uploaded_item = gis.content.add(item_properties=item_properties, data=file_path)
uploaded_item.share(everyone=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_69/989041658.py in <cell line: 0>()
#       8 }
#       9
# ---> 10 uploaded_item = gis.content.add(item_properties=item_properties, data=file_path)
#      11 uploaded_item.share(everyone=True)
#
# /opt/conda/lib/python3.11/site-packages/arcgis/gis/__init__.py in add(self, item_properties, data, thumbnail, metadata, owner, folder, item_id, **kwargs)
#    6938             if "text" in kwargs:
#    6939                 item_properties["text"] = kwargs.pop("text", None)
# -> 6940             itemid = self._portal.add_item(
#    6941                 item_properties,
#    6942                 data,
#
# /opt/conda/lib/python3.11/site-packages/arcgis/gis/_impl/_portalpy.py in add_item(self, item_properties, data, thumbnail, metadata, owner, folder)
# ...
